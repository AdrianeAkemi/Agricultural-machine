# %% [markdown]
# <hr >
# <center>
#     <h1> SME0878 - Mineração Estatística de Dados </h1>
# <center>
# DESAFIO 2
# <center>
# Nomes: Aimê Gomes da Nobrega (Nro USP 11882429)
# <center>
# Adriane Akemi Yamaguti (Nro USP 11915623)
# <center>
# Professor: Jorge Luis Bazan
#
# <hr >

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introdução" data-toc-modified-id="Introdução-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introdução</a></span></li><li><span><a href="#Descrição-dos-dados" data-toc-modified-id="Descrição-dos-dados-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Descrição dos dados</a></span><ul class="toc-item"><li><span><a href="#Instalação-de-pacotes" data-toc-modified-id="Instalação-de-pacotes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Instalação de pacotes</a></span></li><li><span><a href="#Importação-das-bibliotecas" data-toc-modified-id="Importação-das-bibliotecas-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Importação das bibliotecas</a></span></li><li><span><a href="#Funções-auxiliares" data-toc-modified-id="Funções-auxiliares-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Funções auxiliares</a></span></li><li><span><a href="#Leitura-dos-dados" data-toc-modified-id="Leitura-dos-dados-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Leitura dos dados</a></span></li><li><span><a href="#Descrição-das-variáveis" data-toc-modified-id="Descrição-das-variáveis-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Descrição das variáveis</a></span></li></ul></li><li><span><a href="#Limpeza-e-tratamento-dos-dados" data-toc-modified-id="Limpeza-e-tratamento-dos-dados-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Limpeza e tratamento dos dados</a></span><ul class="toc-item"><li><span><a href="#Dados-duplicados" data-toc-modified-id="Dados-duplicados-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Dados duplicados</a></span></li><li><span><a href="#Dados-ausentes" data-toc-modified-id="Dados-ausentes-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Dados ausentes</a></span></li></ul></li><li><span><a href="#Criação-de-features" data-toc-modified-id="Criação-de-features-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Criação de features</a></span></li><li><span><a href="#Análise-Exploratória-dos-dados" data-toc-modified-id="Análise-Exploratória-dos-dados-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Análise Exploratória dos dados</a></span><ul class="toc-item"><li><span><a href="#Estatísticas-descritivas" data-toc-modified-id="Estatísticas-descritivas-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Estatísticas descritivas</a></span><ul class="toc-item"><li><span><a href="#Análise-univariada" data-toc-modified-id="Análise-univariada-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Análise univariada</a></span><ul class="toc-item"><li><span><a href="#Variável-target" data-toc-modified-id="Variável-target-5.1.1.1"><span class="toc-item-num">5.1.1.1&nbsp;&nbsp;</span>Variável target</a></span></li></ul></li><li><span><a href="#Variáveis-numéricas" data-toc-modified-id="Variáveis-numéricas-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Variáveis numéricas</a></span></li><li><span><a href="#Análise-multivariada" data-toc-modified-id="Análise-multivariada-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Análise multivariada</a></span></li></ul></li></ul></li><li><span><a href="#Preparação-dos-dados" data-toc-modified-id="Preparação-dos-dados-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Preparação dos dados</a></span><ul class="toc-item"><li><span><a href="#Seleção-de-features" data-toc-modified-id="Seleção-de-features-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Seleção de features</a></span><ul class="toc-item"><li><span><a href="#Construindo-base-do-modelo" data-toc-modified-id="Construindo-base-do-modelo-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Construindo base do modelo</a></span></li></ul></li></ul></li><li><span><a href="#Modelos" data-toc-modified-id="Modelos-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Modelos</a></span><ul class="toc-item"><li><span><a href="#Regressão-logística" data-toc-modified-id="Regressão-logística-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Regressão logística</a></span></li><li><span><a href="#SVM" data-toc-modified-id="SVM-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>SVM</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Introdução

# %% [markdown]
# O conjunto de dados ChoiceBehaviour.csv contém informações sobre a escolha de um agricultor em relação ao aluguel de maquinaria oferecida por uma mesma companhia. Os dados abrangem 4910 agricultores que precisavam decidir entre três opções de máquinas para aluguel, além da possibilidade de não alugar nenhuma delas. Esses dados simulados são compostos por 11 atributos.
#
# O analista da companhia possui informações relevantes sobre o cliente, como a região de residência do agricultor, os custos de aluguel de cada máquina oferecida, o custo do produto e o preço da máquina base. Porém, essas informações são desconhecidas pelo agricultor. Por sua vez, o agricultor tem acesso apenas à informação do custo para a reparação e aos preços de aluguel das máquinas oferecidas.
#
# Nessa fase inicial de análise, nosso objetivo é compreender as variáveis disponíveis e o problema em questão, a fim de explorar possíveis abordagens sob a perspectiva da empresa. Essa análise mais aprofundada das informações nos ajudará a tomar decisões estratégicas e embasadas, visando otimizar o processo de aluguel de máquinas oferecidas aos trabalhadores rurais.

# %% [markdown]
# <img src="data/maquinas.png"
#      align="center"
#      width="500" />

# %% [markdown]
# ## Descrição dos dados

# %% [markdown]
# Nesta etapa, realizamos a instalaçào e a importação das bibliotecas, criamos as funções auxiliares para o projeto, leitura do dataset e, por fim, a descrição das variáveis.

# %% [markdown]
# ### Instalação de pacotes

# %%
# %pip install catboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import catboost as cb
import warnings
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_curve, roc_auc_score, classification_report
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn import metrics
import random

# %%
# import pandas as pd
# import numpy as np
# import plotly.express as px
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_classif
# from scipy import stats
# import seaborn as sns
# import matplotlib.pyplot as plt
# import catboost as cb
# import warnings
# warnings.filterwarnings("ignore")
# from sklearn.cluster import KMeans
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import RepeatedStratifiedKFold
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.metrics import roc_curve, roc_auc_score
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn import metrics
# import random
# from sklearn.svm import SVC
# from imblearn.over_sampling import SMOTE
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import classification_report
# from sklearn.model_selection import train_test_split, cross_val_score
# import numpy as np
# from sklearn.metrics import classification_report
# from sklearn.metrics import roc_curve, roc_auc_score
# from imblearn.under_sampling import RandomUnderSampler
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import classification_report
# from sklearn.model_selection import train_test_split, cross_val_score
# import numpy as np
# import matplotlib.pyplot as plt
# from imblearn.under_sampling import RandomUnderSampler
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import classification_report
# from sklearn.model_selection import train_test_split, cross_val_score
# import numpy as np

random.seed(5143023)
# from google.colab import drive
import os

# Exibetodas as colunas
pd.set_option('display.max_columns', None)

data = pd.read_excel("data/ChoiceBehaviour.xlsx", dtype={'Regiao':str, 'Id': str, 'Resposta': str})

# seed para estudo da reprodutibilidade
seed = 11915623

# %% [markdown]
# ### Funções auxiliares

# %%
def Lucro(row):
    if row.Resposta == '1':
      return row.Pmaquina1 - row.Cmaquina1
    elif row.Resposta == '2':
      return row.Pmaquina2 - row.Cmaquina2
    elif row.Resposta == '3':
      return row.Pmaquina3 - row.Cmaquina3
    else:
      return 0

# %% [markdown]
# ### Leitura dos dados

# %%
print(f"O dataframe possui {data.shape[0]} linhas e {data.shape[1]} colunas.")
data.head()
# Out:
# O dataframe possui 4910 linhas e 12 colunas.
#   Id Regiao  Prima  CustoProduto  Pmaquinabase  Pmaquina1  Pmaquina2  \
# 0  1    560   5073       15742.0        858.20    1268.82    1564.31
# 1  2    558   1618       33277.0       1008.85    1411.35    1457.82
# 2  3    554   1520       37175.0        910.08    1409.37    1575.85
# 3  4    555   2238       58449.0       2218.16    3163.57    4220.16
# 4  5    554   3781       10349.0        628.48    1101.97    1398.68
#
#    Pmaquina3    Cmaquina1  Cmaquina2    Cmaquina3 Resposta
# 0    1748.41   959.199559     858.20   696.090496        1
# 1    1583.61  1095.900007    1008.85   976.691531        1
# 2    1630.02   941.364090     910.08   813.934987        1
# 3    4350.34  2286.583962    2218.16  1662.805304        1
# 4    1705.71   766.440230     628.48   495.156938        1

# %% [markdown]
# ### Descrição das variáveis

# %% [markdown]
# A seguir, ilustramos o dicionário desses dados:
#
# - Regiao: Local onde o agricultor reside.
# - Prima: Valor que o agricultor precisa pagar para a reparação da máquina.
# - CustoProduto: Custo estimado da maquinaria no momento do aluguel para o agricultor.
# - Pmáquinabase: Preço do aluguel da máquina base para dar cobertura ao assegurado.
# - Pmáquina1: Preço do aluguel da máquina 1 oferecido ao agricultor.
# - Pmáquina2: Preço do aluguel da máquina 2 oferecido ao agricultor.
# - Pmáquina3: Preço do aluguel da máquina 3 oferecido ao agricultor.
# - Cmáquina1: Custo do aluguel da máquina 1 oferecido ao agricultor.
# - Cmáquina2: Custo do aluguel da máquina 2 oferecido ao agricultor.
# - Cmáquina3: Custo do aluguel da máquina 3 oferecido ao agricultor.
# - Resposta: Indicador da escolha do agricultor, sendo 1 para aluguel da máquina 1, 2 para aluguel da máquina 2, 3 para aluguel da máquina 3 e 0 para o caso em que o agricultor decide não alugar nenhuma máquina oferecida.
# - Resposta2: Outro indicador da escolha do agricultor, onde 1 representa o aluguel de uma máquina e 0 indica que o agricultor não alugou nenhuma máquina.
#
# Esses dados oferecem insights valiosos sobre o comportamento de escolha dos agricultores em relação às opções de aluguel de maquinaria. Através de análises e modelos estatísticos, é possível explorar padrões e tomar decisões informadas para otimizar o processo de locaçao dessas máquinas.

# %% [markdown]
# Podemos verificar os tipos de cada variável e a quantidade de valores não nulos:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4910 entries, 0 to 4909
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            4910 non-null   object
#  1   Regiao        4910 non-null   object
#  2   Prima         4910 non-null   int64
#  3   CustoProduto  4910 non-null   float64
#  4   Pmaquinabase  4910 non-null   float64
#  5   Pmaquina1     4910 non-null   float64
#  6   Pmaquina2     4910 non-null   float64
#  7   Pmaquina3     4910 non-null   float64
#  8   Cmaquina1     4910 non-null   float64
#  9   Cmaquina2     4910 non-null   float64
#  10  Cmaquina3     4910 non-null   float64
#  11  Resposta      4910 non-null   object
# dtypes: float64(8), int64(1), object(3)
# memory usage: 460.4+ KB

# %% [markdown]
# ## Limpeza e tratamento dos dados

# %% [markdown]
# ### Dados duplicados

# %% [markdown]
# Realizamos uma checagem em nosso conjunto de dados a fim de identificar e lidar com possíveis inconsistências provenientes de dados duplicados. Para preservar a integridade dos dados originais, criamos uma cópia do DataFrame antes de prosseguir com a verificação.
#
# Durante o processo, uma nova coluna chamada "check_dup" foi adicionada ao DataFrame, recebendo valores booleanos que indicam se cada linha está duplicada ou não. Utilizamos a função "duplicated()" para garantir que todas as ocorrências duplicadas fossem marcadas como "True" por meio do argumento "keep=False".
#
# Por fim, realizamos uma filtragem utilizando a função "query()" para selecionar apenas as linhas em que "check_dup" é igual a "True", ou seja, aquelas em que ocorrem duplicações. Essas linhas duplicadas são retornadas como resultado da consulta, permitindo que sejam tratadas conforme necessário.

# %%
# Verifica a existência de dados duplicados
data_aux = data.copy()
data_aux['check_dup'] = data_aux.duplicated(keep=False)
print(data_aux.duplicated().sum())
# Aponta onde ocorreu a anomalia 
data_aux.query("check_dup == True")
# Out:
# 1
#         Id Regiao  Prima  CustoProduto  Pmaquinabase  Pmaquina1  Pmaquina2  \
# 3368  3310    557   3362       88275.0       1119.98    2223.01     2652.0
# 3369  3310    557   3362       88275.0       1119.98    2223.01     2652.0
#
#       Pmaquina3   Cmaquina1  Cmaquina2   Cmaquina3 Resposta  check_dup
# 3368    2774.86  1171.86565    1119.98  938.810988        0       True
# 3369    2774.86  1171.86565    1119.98  938.810988        0       True

# %%
# Porcentagem dos valores duplicados
duplicated_pct = round(data.duplicated().sum() / len(data) * 100, 2)
print(f"Existem {duplicated_pct}% linhas duplicadas neste dataset.")
# Out:
# Existem 0.02% linhas duplicadas neste dataset.

# %% [markdown]
# Notamos que existem dados duplicados na base. Dessa forma, decidimos removê-los.

# %%
# Remove dados duplicados
data.drop_duplicates(inplace= True, ignore_index= True)

# Mostramos o tamanho do dataframe após o tratamento
print(f"O dataframe possui {data.shape[0]} linhas e {data.shape[1]} colunas.")
data.head()
# Out:
# O dataframe possui 4909 linhas e 12 colunas.
#   Id Regiao  Prima  CustoProduto  Pmaquinabase  Pmaquina1  Pmaquina2  \
# 0  1    560   5073       15742.0        858.20    1268.82    1564.31
# 1  2    558   1618       33277.0       1008.85    1411.35    1457.82
# 2  3    554   1520       37175.0        910.08    1409.37    1575.85
# 3  4    555   2238       58449.0       2218.16    3163.57    4220.16
# 4  5    554   3781       10349.0        628.48    1101.97    1398.68
#
#    Pmaquina3    Cmaquina1  Cmaquina2    Cmaquina3 Resposta
# 0    1748.41   959.199559     858.20   696.090496        1
# 1    1583.61  1095.900007    1008.85   976.691531        1
# 2    1630.02   941.364090     910.08   813.934987        1
# 3    4350.34  2286.583962    2218.16  1662.805304        1
# 4    1705.71   766.440230     628.48   495.156938        1

# %% [markdown]
# Essa abordagem de verificação e identificação de dados duplicados é fundamental para garantir a qualidade e a confiabilidade dos dados utilizados em análises posteriores, contribuindo para uma tomada de decisão mais precisa e embasada.

# %% [markdown]
# ### Dados ausentes

# %% [markdown]
# Também verificamos que neste conjunto de dados não possui nenhum valor faltante. Portanto, não realizamos nenhum tratamento.

# %%
# Mostra a quantidade de valores nulos em cada coluna
data.isnull().sum()
# Out:
# Id              0
# Regiao          0
# Prima           0
# CustoProduto    0
# Pmaquinabase    0
# Pmaquina1       0
# Pmaquina2       0
# Pmaquina3       0
# Cmaquina1       0
# Cmaquina2       0
# Cmaquina3       0
# Resposta        0
# dtype: int64

# %% [markdown]
# ## Criação de features

# %% [markdown]
# - **Alugou:** Indica se houve aceitação de pelo menos uma das propostas, correspondendo à Resposta 2 no enunciado do problema.
#
# - **RatioPC1:** Representa a razão entre o custo para a empresa e o preço para o cliente da Proposta 1. Valores altos de RatioPC indicam que o preço está baixo em relação ao custo. Esperamos uma correlação positiva entre RatioPC1 e a escolha da proposta 1. O mesmo princípio se aplica às variáveis RatioPC2 e RatioPC3.
#
# - **Ratio1:** Enquanto a RatioPC utiliza os valores de custo da empresa que não são informados aos clientes, a característica Ratio1 compara apenas os dados informados ao cliente. É a razão entre a média dos preços das outras propostas (2 e 3) e o preço da proposta 1. Indica o quão atraente uma proposta parece em relação às outras. Também esperamos uma correlação positiva entre Ratio1 e a escolha da proposta 1. O mesmo se aplica às variáveis Ratio2 e Ratio3.
#
# - **Escolheu1:** Indica se a proposta 1 foi aceita ou não. Embora não seja utilizada nas estimações, essa variável ajuda a avaliar as correlações. O mesmo se aplica às variáveis Escolheu2 e Escolheu3.
#
# - **PrecoCusto:** Representa a razão entre o custo da máquina e o preço médio das propostas de aluguel. Quanto menores forem os preços, maior será o valor da variável PrecoCusto. Esperamos uma correlação positiva entre PrecoCusto e a variável Alugou.
#
# - **Lucro:** Quantifica o lucro de cada proposta. Se o cliente não alugou a máquina, o lucro é zero. Caso uma proposta seja aceita, o lucro é calculado como a diferença entre o preço e o custo da proposta correspondente.

# %%
data['Alugou'] = np.where(data['Resposta'] == '0', '0', '1')
data['RatioPC1'] =data['Cmaquina1']/data['Pmaquina1']
data['RatioPC2'] =data['Cmaquina2']/data['Pmaquina2']
data['RatioPC3'] =data['Cmaquina3']/data['Pmaquina3']
data['Ratio1'] = ((data['Pmaquina2']+ data['Pmaquina3'])/2) / data['Pmaquina1']
data['Ratio2'] = ((data['Pmaquina1']+ data['Pmaquina3'])/2) / data['Pmaquina2']
data['Ratio3'] = ((data['Pmaquina2']+ data['Pmaquina1'])/2) / data['Pmaquina3']
data['Escolheu1'] = np.where(data['Resposta'] == '1', '1', '0')
data['Escolheu2'] = np.where(data['Resposta'] == '2', '1', '0')
data['Escolheu3'] = np.where(data['Resposta'] == '3', '1', '0')
data['PrecoCusto'] = (3*data['CustoProduto'])/(data['Cmaquina1']+data['Cmaquina3']+data['Cmaquina3'])
data['Lucro'] = data.apply(Lucro, axis='columns')

# %%
# Mostramos o tamanho do dataframe após o a criação de novas features
print(f"O dataframe possui {data.shape[0]} linhas e {data.shape[1]} colunas.")
data.head()
# Out:
# O dataframe possui 4909 linhas e 24 colunas.
#   Id Regiao  Prima  CustoProduto  Pmaquinabase  Pmaquina1  Pmaquina2  \
# 0  1    560   5073       15742.0        858.20    1268.82    1564.31
# 1  2    558   1618       33277.0       1008.85    1411.35    1457.82
# 2  3    554   1520       37175.0        910.08    1409.37    1575.85
# 3  4    555   2238       58449.0       2218.16    3163.57    4220.16
# 4  5    554   3781       10349.0        628.48    1101.97    1398.68
#
#    Pmaquina3    Cmaquina1  Cmaquina2    Cmaquina3 Resposta Alugou  RatioPC1  \
# 0    1748.41   959.199559     858.20   696.090496        1      1  0.755978
# 1    1583.61  1095.900007    1008.85   976.691531        1      1  0.776491
# 2    1630.02   941.364090     910.08   813.934987        1      1  0.667933
# 3    4350.34  2286.583962    2218.16  1662.805304        1      1  0.722786
# 4    1705.71   766.440230     628.48   495.156938        1      1  0.695518
#
# ...

# %% [markdown]
# ## Análise Exploratória dos dados

# %% [markdown]
# ### Estatísticas descritivas

# %% [markdown]
# Vamos dar uma olhada nas estatísticas descritivas para as variáveis numéricas:

# %%
data.describe().T.style.format(precision= 2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b5f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b5f2_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_8b5f2_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_8b5f2_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_8b5f2_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_8b5f2_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_8b5f2_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_8b5f2_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_8b5f2_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b5f2_level0_row0" class="row_heading level0 row0" >Prima</th>
#       <td id="T_8b5f2_row0_col0" class="data row0 col0" >4909.00</td>
# ...

# %% [markdown]
# E também nas variáveis categóricas:

# %%
data[['Id','Regiao','Resposta', 'Alugou', 'Escolheu1', 'Escolheu2', 'Escolheu3']].describe()
# Out:
#           Id Regiao Resposta Alugou Escolheu1 Escolheu2 Escolheu3
# count   4909   4909     4909   4909      4909      4909      4909
# unique  4168     13        4      2         2         2         2
# top     3310    554        0      0         0         0         0
# freq     742    986     4329   4329      4757      4625      4765

# %% [markdown]
# Ao analisar os resultados, identificamos que há quatro respostas possíveis. Além disso, fica evidente que os dados estão desequilibrados, uma vez que há 4.329 agricultores que escolheram não alugar nenhuma máquina. Também notamosque os agricultores estão distribuídos em 13 regiões, sendo que na região '554' residem aproximadamente 986 agricultores.

# %% [markdown]
# #### Análise univariada

# %% [markdown]
# Vamos separar as variáveis numéricas das categóricas e realizar a análise univariada:

# %%
dados_numericos = data[['Prima', 'CustoProduto', 'Pmaquinabase', 'Pmaquina1',
       'Pmaquina2', 'Pmaquina3', 'Cmaquina1', 'Cmaquina2', 'Cmaquina3',
       'RatioPC1', 'RatioPC2', 'RatioPC3', 'Ratio1',
       'Ratio2', 'Ratio3', 'PrecoCusto','Lucro']]
dados_categoricos = data[['Id','Regiao','Resposta', 'Escolheu1',
                          'Escolheu2', 'Escolheu3']]
dados_target = data[['Alugou']]

# %% [markdown]
# ##### Variável target

# %%
# Configurando o tamanho da figura
plt.figure(figsize=(8, 6))

# Criando o countplot
ax = sns.countplot(data=dados_target, x='Alugou',
                  palette='Set2')

# Convertendo as contagens em proporções
total = len(dados_target)
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().text(p.get_x() + p.get_width() / 2,
                   height / total,
                   f'{height/total:.2%}',
                   ha='center', va='bottom',
                  fontsize=15)

# Adicionando os valores em cima das barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',
                (p.get_x() + p.get_width() / 2.,
                 p.get_height()), ha='center',
                va='center', xytext=(0, 5),
                textcoords='offset points',
                fontsize=15)

# Configurando o título e os rótulos dos eixos
plt.title("Distribuição da variável 'Alugou'",
         fontsize=20)

# Eixo x
plt.xlabel('Valores', fontsize=15)
plt.xticks(fontsize=15)
# Eixo y
plt.ylabel('Contagem', fontsize=15)
plt.ylim(0, 5000) # Aumenta o limite
plt.yticks(fontsize=15) # Aumenta o tamanho da fonte

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Podemos notar que os dados estão bem desbalanceados e aproximadamente 12% dos agricultores alugaram uma das máquinas. Este desbalanceamento das classes pode impactar a capacidade de generalização do modelo.

# %% [markdown]
# #### Variáveis numéricas

# %%
# Configurando o tamanho da figura
plt.figure(figsize=(12, 20))

# Loop para criar os boxplots
for i, coluna in enumerate(dados_numericos.columns):
    plt.subplot(6, 4, i+1)
    sns.boxplot(data=dados_numericos[coluna])
    plt.title(f'Boxplot - {coluna}')
    plt.xlabel(coluna)
    plt.ylabel('Valores')

# Ajustando o espaçamento entre os subplots
plt.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# Com base nas estatísticas descritivas e nos gráficos de boxplot,  podemos observar que:
#
# - Prima, Cmaquina1, Cmaquina2 e Cmaquina3 possuem média e mediana próximas, sugerindo uma distribuição aproximadamente simétrica. O desvio padrão indica uma variação considerável nos valores.
#
# - Pmaquina1, Pmaquina2, Pmaquina3, PrecoCusto, CustoProduto e Pmaquinabase apresentam média maior que a mediana, indicando uma possível assimetria positiva. Além disso, os desvios padrão indicam uma variação considerável nos valores. É importante observar que as variáveis relacionadas às máquinas (Pmaquina1, Pmaquina2 e Pmaquina3) possuem valores extremos.
#
# - RatioPC1, RatioPC2 e RatioPC3 representam proporções e têm média próxima à mediana, sugerindo uma distribuição aproximadamente simétrica. Os desvios padrão indicam uma variação moderada nos valores.
#
# - Ratio1, Ratio2 e Ratio3 também representam proporções. Apresentam média e mediana semelhantes, indicando uma distribuição simétrica. Os desvios padrão são relativamente baixos, sugerindo uma variação menor nos valores.
#
# - Lucro mostra uma possível assimetria positiva, com média maior que a mediana. O desvio padrão indica uma variação considerável nos valores. Existem valores extremos, tanto negativos quanto positivos.

# %% [markdown]
# #### Análise multivariada

# %%
# Calculando a matriz de correlação
correlation_matrix = data.corr()

# Plotando a heatmap da matriz de correlação
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='RdYlBu')
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# Podemos notar que:
#
# - As variáveis relacionadas aos custos (Prima, CustoProduto, Pmaquinabase, Pmaquina1, Pmaquina2, Pmaquina3, Cmaquina1, Cmaquina2, Cmaquina3) apresentam correlações positivas entre si. Isso sugere que elas estão relacionadas e tendem a variar juntas.
#
# - RatioPC1, RatioPC2 e RatioPC3, que representam proporções, apresentam correlações positivas moderadas entre si. Isso indica que elas estão relacionadas e tendem a se mover na mesma direção.
#
# - Ratio1, Ratio2 e Ratio3 também apresentam correlações positivas entre si, embora sejam mais fracas em comparação com as proporções anteriores. Isso sugere uma associação entre essas variáveis, mas menos pronunciada.
#
# - PrecoCusto tem uma correlação positiva moderada com CustoProduto, o que indica uma relação entre o preço de custo e o custo do produto.
#
# - Lucro mostra correlações fracas com as outras variáveis, indicando uma associação menos evidente.

# %% [markdown]
# Vamos separar a variável 'Alugou' em duas classes (0- não alugou e 1- alugou) e analisar a matriz de correlação:

# %%
for response in data['Alugou'].unique():
    # Filtrando os dados para a resposta atual
    filtered_data = data[data['Alugou'] == response]

    # Calculando a matriz de correlação
    correlation_matrix = filtered_data.corr()

    # Plotando o mapa de calor da matriz de correlação
    plt.figure(figsize=(12, 12))
    sns.heatmap(correlation_matrix, annot=True, cmap='RdYlBu')
    plt.title(f'Matriz de Correlação - Alugou: {response}')
    plt.show()

# %% [markdown]
# No geral, as correlações entre as variáveis não sofreram mudanças significativas em relação à análise anterior.

# %% [markdown]
# ## Preparação dos dados

# %% [markdown]
# ### Seleção de features

# %% [markdown]
# No contexto de aluguel de máquinas, é importante levar em consideração a relevância das variáveis utilizadas no modelo. Nesse sentido, optamos por não incluir a variável de custo, uma vez que ela é uma informação relevante apenas para quem aluga as máquinas, não sendo de conhecimento do cliente. O foco do nosso modelo é prever a decisão do cliente, levando em consideração apenas o preço final da máquina.

# %% [markdown]
# #### Construindo base do modelo

# %%
# tomar amostra

# set seed
np.random.seed(seed)

# tomar 2000 do df
df_sample = data.sample(n=2000)

# salvar em um csv
df_sample.to_csv('data/baseprincipal.txt', sep='\t', index=False)

# %%
# criar amostra de treino e teste, seguinto a proporcao de 70 e 30 respectivamente
df_train = df_sample.sample(frac=0.7)
df_test = df_sample.drop(df_train.index)

# salvar base teste como baseteste.csv
df_test.to_csv('data/baseteste.txt', sep='\t', index=False, header= True)

# salvar base treino como basetreno.csv
df_train.to_csv('data/basetreino.txt', sep='\t', index=False, header= True)

# %% [markdown]
# ## Modelos

# %% [markdown]
# Existem diversas técnicas de tratar dados desbalanceados, abaixo citamos alguns exemplos:
#
# - **Undersampling:** Reduz o número de observações da classe majoritária para diminuir a diferença entre as categorias;
#
# - **Oversampling:** Cria novas observações da classe minoritária, com o objetivo de igualar a proporção das categorias.

# %% [markdown]
# Existem vários modelos de aprendizado de máquina que podem ser usados para lidar com conjuntos de dados desbalanceados. Dessa forma, escolhemos 2 deles:

# %% [markdown]
# ### Regressão logística

# %% [markdown]
# Embora seja comumente usado para problemas de classificação binária, a regressão logística também pode ser aplicada a conjuntos de dados desbalanceados. A ponderação de classe ou o ajuste dos limiares de decisão podem ser utilizados para tratar o desequilíbrio.

# %%
# Separando as variáveis independentes da variável dependente em treino e teste
X_train, y_train = df_train.drop('Alugou', axis=1), df_train['Alugou']
X_test, y_test = df_test.drop('Alugou', axis=1), df_test['Alugou']

# %% [markdown]
# - Testando com oversamplig:

# %%
# Aplicar SMOTE no conjunto de treinamento
smote = SMOTE(random_state=seed)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Inicializar o modelo de regressão logística
model = LogisticRegression()

# Fazer k-fold cross-validation
k = 5  # Número de folds
scores = cross_val_score(model, X_train_resampled, y_train_resampled, cv=k)

# Treinar o modelo em todos os dados de treinamento com SMOTE
model.fit(X_train_resampled, y_train_resampled)

# Fazer previsões nos dados de teste
y_pred = model.predict(X_test)

# Gerar o relatório de classificação
report = classification_report(y_test, y_pred)

# Imprimir os resultados
print(f"Scores (k-fold cross-validation): {np.mean(scores):.2f} (+/- {np.std(scores):.2f})")
print("Classification Report:")
print(report)
# Out:
# Scores (k-fold cross-validation): 1.00 (+/- 0.00)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       527
#            1       0.99      1.00      0.99        73
#
#     accuracy                           1.00       600
#    macro avg       0.99      1.00      1.00       600
# weighted avg       1.00      1.00      1.00       600
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# Podemos concluir que o modelo possui um desempenho excelente na classificação das duas classes. Ele é capaz de identificar corretamente a maioria das instâncias positivas e negativas, obtendo altas precision, recall e f1-score.

# %%
# Converter os rótulos para valores numéricos
y_test_numeric = np.array(y_test, dtype=int)

# Calcular as probabilidades das classes
y_pred_prob = model.predict_proba(X_test)[:, 1]  # Probabilidades da classe positiva

# Calcular a taxa de verdadeiros positivos (TPR), taxa de falsos positivos (FPR) e limiares
fpr, tpr, thresholds = roc_curve(y_test_numeric, y_pred_prob)

# Calcular a AUC
auc_score = roc_auc_score(y_test_numeric, y_pred_prob)

# Plotar a curva ROC
plt.plot(fpr, tpr, label='Curva ROC (AUC = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], 'k--')  # Linha de referência (AUC = 0.5)
plt.xlabel('Taxa de Falsos Positivos (FPR)')
plt.ylabel('Taxa de Verdadeiros Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# Imprimir o valor da AUC
print('AUC:', auc_score)
# Out:
# AUC: 1.0

# %% [markdown]
# - Testando com undersamplig:

# %%
# Aplicar Random Undersampling no conjunto de treinamento
undersampler = RandomUnderSampler(random_state=seed)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# Inicializar o modelo de regressão logística
model = LogisticRegression()

# Fazer k-fold cross-validation
k = 5  # Número de folds
scores = cross_val_score(model, X_train_resampled, y_train_resampled, cv=k)

# Treinar o modelo em todos os dados de treinamento com undersampling
model.fit(X_train_resampled, y_train_resampled)

# Fazer previsões nos dados de teste
y_pred = model.predict(X_test)

# Gerar o relatório de classificação
report = classification_report(y_test, y_pred)

# Imprimir os resultados
print(f"Scores (k-fold cross-validation): {np.mean(scores):.2f} (+/- {np.std(scores):.2f})")
print("Classification Report:")
print(report)
# Out:
# Scores (k-fold cross-validation): 0.99 (+/- 0.01)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       527
#            1       0.91      1.00      0.95        73
#
#     accuracy                           0.99       600
#    macro avg       0.96      0.99      0.97       600
# weighted avg       0.99      0.99      0.99       600
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# Podemos concluir que o modelo possui um bom desempenho em identificar corretamente a classe majoritária (0), mas pode ter alguma dificuldade em identificar corretamente a classe minoritária (1).

# %%
# Converter os rótulos para valores numéricos
y_test_numeric = np.array(y_test, dtype=int)

# Calcular as probabilidades das classes
y_pred_prob = model.predict_proba(X_test)[:, 1]  # Probabilidades da classe positiva

# Calcular a taxa de verdadeiros positivos (TPR), taxa de falsos positivos (FPR) e limiares
fpr, tpr, thresholds = roc_curve(y_test_numeric, y_pred_prob)

# Calcular a AUC
auc_score = roc_auc_score(y_test_numeric, y_pred_prob)

# Plotar a curva ROC
plt.plot(fpr, tpr, label='Curva ROC (AUC = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], 'k--')  # Linha de referência (AUC = 0.5)
plt.xlabel('Taxa de Falsos Positivos (FPR)')
plt.ylabel('Taxa de Verdadeiros Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# Imprimir o valor da AUC
print('AUC:', auc_score)
# Out:
# AUC: 0.9999220191832808

# %% [markdown]
# Criamos uma tabela para facilitar a comparação dos resultados:
#
#
# | Métrica    | Oversamplig                   | Undersamplig                  |
# |------------|-------------------------------|-------------------------------|
# | Precision  | Classe 0: 1.00<br>Classe 1: 1.00 | Classe 0: 1.00<br>Classe 1: 0.94 |
# | Recall     | Classe 0: 1.00<br>Classe 1: 0.99 | Classe 0: 0.99<br>Classe 1: 0.99 |
# | F1-Score   | Classe 0: 1.00<br>Classe 1: 0.99 | Classe 0: 0.99<br>Classe 1: 0.96 |
# | Accuracy   | 1.00                          | 0.99                          |
#
# Ambos os métodos apresentam resultados satisfatórios, com altos valores de precision, recall, f1-score e acurácia. No entanto, o oversampling mostra um desempenho um pouco melhor em termos de precision para a classe 1, enquanto o undersampling apresenta um f1-score ligeiramente inferior para a classe 1. Dessa forma, optamos por aplicar o método de oversampling nos dados.

# %% [markdown]
# ### SVM

# %% [markdown]
# Escolhemos o Support Vector Machines (SVM), pois é um modelo de aprendizado de máquina que pode ser utilizado para lidar com conjuntos de dados desbalanceados. O SVM busca encontrar um hiperplano ótimo que separa as classes no espaço de características, maximizando a margem entre as classes.

# %% [markdown]
# - Testando com oversamplig:

# %%
# Aplicar SMOTE no conjunto de treinamento
smote = SMOTE(random_state= seed)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Criar e treinar o modelo SVM
svm = SVC(class_weight='balanced', probability=True)
svm.fit(X_train_resampled, y_train_resampled)

# Fazer previsões no conjunto de teste
y_pred = svm.predict(X_test)

# Exibir métricas de classificação
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83       527
#            1       0.27      0.68      0.38        73
#
#     accuracy                           0.73       600
#    macro avg       0.61      0.71      0.61       600
# weighted avg       0.86      0.73      0.77       600

# %% [markdown]
# Usamos o parâmetro class_weight='balanced' para lidar com o desbalanceamento. Isso atribui pesos diferentes às classes durante o treinamento, de forma que a classe minoritária tenha uma influência maior.

# %% [markdown]
# Podemos concluir que o modelo tem um desempenho melhor na previsão dos casos negativos (classe 0), apresentando uma alta precisão e um recall razoável. No entanto, o desempenho na previsão dos casos positivos (classe 1) é mais baixo, com uma precisão e recall mais baixos. Isso indica que o modelo tem dificuldade em identificar corretamente os casos positivos.

# %%
y_test = y_test.astype(int)

# Obter as probabilidades previstas
proba = svm.predict_proba(X_test)[:, 1]

# Calcular a curva ROC
fpr, tpr, thresholds = roc_curve(y_test, proba)

# Calcular a AUC-ROC
auc_roc = roc_auc_score(y_test, proba)

# Exibir a curva ROC
plt.plot(fpr, tpr, label='Curva ROC (AUC = {:.2f})'.format(auc_roc))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# Imprimir o valor da AUC
print('AUC:', auc_roc)
# Out:
# AUC: 0.7967040108133399

# %% [markdown]
# - Testando com undersampling

# %%
y_test = y_test.astype(str)

# Aplicar undersampling na classe majoritária
undersampler = RandomUnderSampler(random_state=seed)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# Criar e treinar o modelo SVM
svm = SVC(probability=True, class_weight='balanced')  # Definir probability=True para obter predict_proba
svm.fit(X_train_resampled, y_train_resampled)

# Fazer previsões no conjunto de teste
y_pred = svm.predict(X_test)

# Exibir métricas de classificação
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.59      0.71       527
#            1       0.16      0.56      0.25        73
#
#     accuracy                           0.58       600
#    macro avg       0.53      0.57      0.48       600
# weighted avg       0.82      0.58      0.66       600

# %% [markdown]
# Observamos que o desempenho do modelo é relativamente baixo. A precisão, recall e F1-score para a classe 1 (casos positivos) são bastante baixos, indicando que o modelo tem dificuldade em identificar corretamente esses casos. Isso pode ser problemático em um cenário em que a identificação correta dos casos positivos é importante.

# %%
y_test = y_test.astype(int)

# Obter as probabilidades previstas
proba = svm.predict_proba(X_test)[:, 1]

# Calcular a curva ROC
fpr, tpr, thresholds = roc_curve(y_test, proba)

# Calcular a AUC-ROC
auc_roc = roc_auc_score(y_test, proba)

# Exibir a curva ROC
plt.plot(fpr, tpr, label='Curva ROC (AUC = {:.2f})'.format(auc_roc))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# Imprimir o valor da AUC
print('AUC:', auc_roc)
# Out:
# AUC: 0.6405344285305814

# %% [markdown]
# Criamos uma tabela para facilitar a comparação dos resultados:
#
# | Métrica    | Oversamplig                   | Undersamplig                  |
# |------------|-------------------------------|-------------------------------|
# | Precision  | Classe 0: 0.94<br>Classe 1: 0.27 | Classe 0: 0.91<br>Classe 1: 0.16 |
# | Recall     | Classe 0: 0.74<br>Classe 1: 0.68 | Classe 0: 0.59<br>Classe 1: 0.56 |
# | F1-Score   | Classe 0: 0.83<br>Classe 1: 0.38 | Classe 0: 0.71<br>Classe 1: 0.25 |
# | Accuracy   | 0.73                          | 0.58                          |
#
# Na tabela acima, são resumidos os principais valores de cada relatório, incluindo as métricas de precisão, recall, F1-score e acurácia para as duas classes (Classe 0 e Classe 1). Portanto, com base nessas métricas, o modelo descrito no Relatório 1 seria considerado melhor em relação ao modelo descrito no Relatório 2. Ele apresenta um desempenho geralmente mais alto em termos de precisão, recall, F1-score e acurácia.

# %% [markdown]
# # Conclusão

# %% [markdown]
# Ao concluir este trabalho, enfrentamos o desafio do desbalanceamento de dados em nosso conjunto de dados. A presença desse desbalanceamento pode afetar negativamente o desempenho do modelo de aprendizado de máquina, levando a resultados enviesados e imprecisos. Para lidar com essa questão, aplicamos técnicas de oversampling e undersampling.
#
# No entanto, ao avaliar o desempenho do modelo, observamos uma acurácia perfeita em todos os métodos de balanceamento de dados, o que levanta dúvidas sobre a implementação ou o processo de avaliação. Utilizamos métricas adicionais, como precisão, recall, F1-score e AUC-ROC, para obter uma visão mais completa e precisa do desempenho do modelo.
#
# É fundamental reconhecer que o desbalanceamento de classes é um desafio comum e que alcançar resultados perfeitos nem sempre é viável ou realista. Devemos interpretar os resultados de forma crítica, considerando o contexto específico do problema e as implicações do enviesamento das classes.
#
# Concluímos que é necessário aprofundar nossa análise, revisar o código e os dados, e realizar ajustes adicionais para obter resultados confiáveis e relevantes. Ao enfrentar o desbalanceamento de dados, devemos sempre buscar aprimorar nossas abordagens, utilizar métricas adequadas e adotar estratégias que melhorem a capacidade de nosso modelo de generalizar corretamente para todas as classes envolvidas.
